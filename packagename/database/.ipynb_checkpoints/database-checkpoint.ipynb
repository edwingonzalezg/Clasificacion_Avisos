# %%
# %pip install openpyxl
# %pip install unidecode
# Out:
# Requirement already satisfied: openpyxl in c:\users\dmnag\anaconda3\envs\env2\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\dmnag\anaconda3\envs\env2\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unidecode in c:\users\dmnag\anaconda3\envs\env2\lib\site-packages (1.3.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

def cargar_datos():
    
    df_total = pd.read_excel('qFallas.xlsx')
    df_bow = pd.read_excel('BoW clasificación de avisos.xlsx')
    df_dic_da = pd.read_excel('Diccionario DA.xlsx', index_col='Palabra')
    df_dic_te = pd.read_excel('Diccionario TE.xlsx', index_col='Palabra')
    
    display(df_total)
    display(df_bow)
    display(df_dic_da)
    display(df_dic_te)

# %%
import re
import numpy as np
from unidecode import unidecode

def preprocesamiento():
    global df_total
    # Convertimos los DataFrames a diccionarios
    dict_da = df_dic_da.to_dict()
    dict_te = df_dic_te.to_dict()

    # Expresión regular
    regex = r"\w+-?\d+|\d+-?\w+|[^a-z ]| de | la | el | a "

    # Función de transformación "Descripción del Aviso"
    def transform_da(text):
        text = unidecode(text)
        text = text.lower()
        text = re.sub(re.compile(regex), " ", text)
        text = re.sub(re.compile(r" +"), " ", text)
        text = text.strip()
        text = text.split()
        text = [token for token in text if len(token) > 1]
        text = [token.replace(token,dict_da['Corrector'].get(token, token)) for token in text]
        return " ".join(text)

    # Función de transformación "Texto Explicativo"
    def transform_te(text):
        text = unidecode(text)
        text = text.lower()
        text = re.sub(re.compile(regex), " ", text)
        text = re.sub(re.compile(r" +"), " ", text)
        text = text.strip()
        text = text.split()
        text = [token for token in text if len(token) > 1]
        text = [token.replace(token,dict_te['Corrector'].get(token, token)) for token in text]
        return " ".join(text)

    # Agregar columnas Nuevas
    df_total['Descripción preprocesado'] = df_total['Descripción'].apply(transform_da)
    df_total['Texto explicativo preprocesado'] = df_total['Texto explicativo'].apply(transform_te)

    # Visualizamos el resultado de "Descripción preprocesado"
    display(pd.DataFrame(df_total['Descripción preprocesado']))

    # Visualizamos el resultado de "Texto explicativo preprocesado"
    display(pd.DataFrame(df_total['Texto explicativo preprocesado']))

    # Creación Columnas
    df_total = df_total.assign(Clasificación = np.nan)
    df_total = df_total.assign(Proceso_gestión = np.nan)
    df_total = df_total.assign(Tipo_falla_SP = np.nan)

    # Renombramiento Columnas
    df_total.rename({'Proceso_gestión':'Proceso gestión', 'Tipo_falla_SP':'Tipo falla / SP'}, axis=1, inplace=True)

    # Generamos la información con las características del DataFrame
    display(df_total.info())

    # Mostramos el tamañao del nuevo DataFrame
    display(df_total.shape)

# %%
cargar_datos()
# Out:
#            Aviso                               Descripción Status del sistema  \
# 0       10293264      Alta temperatura en rodamiento bomba          MECE ORAS
# 1       10293467            TUBING DE VENTEO EN MAL ESTADO          MECE ORAS
# 2       10293691             valvula presenta atascamiento          MECE ORAS
# 3       10293692             valvula presenta atascamiento          MECE ORAS
# 4       10293695  Falla señal de activación en HMI DLC5701          MECE ORAS
# ...          ...                                       ...                ...
# 29966  120025862  Embrague  Unidad 40 MON III-FALLA DE EMG               MEAB
# 29967  120025863    ALTO DIFERENCIAL TORRE DE LUBRICANTE A               MEAB
# 29968  120025864   LIT-0554 PRESENTA DESVIACION PARAMETROS               MEAB
# 29969  120025865          Unidad 1 BPC-3410-FALLA EMBRAGUE               MEAB
# 29970  120025866         Unidad  -4420 BAJO  NIVEL DE AGUA               MEAB
#
#       Status de usuario      Orden Clase de orden  \
# 0                  AVDG  4603258.0           Z2PM
# 1                  AVDG  4606021.0           Z2PM
# 2                  AVDG  4625591.0           Z2PM
# 3                  AVDG  4625592.0           Z2PM
# 4                  AVDG  4601806.0           Z2PM
# ...                 ...        ...            ...
# 29966              AVAB        NaN            NaN
# 29967              AVAB        NaN            NaN
# 29968              AVAB        NaN            NaN
# 29969              AVAB        NaN            NaN
# 29970              AVAB        NaN            NaN
#
#                Status del sistema (orden) Status de usuario (orden)  \
# 0      CERR NOTI CEsC KKMP MOVM NLIQ PREC            CTOK OTAU OTEF
# 1           CERR CEsC DMNV KKMP NLIQ PREC                 CTCA OSPD
# 2           CERR CEsC DMNV KKMP NLIQ PREC                 CTCA OSPD
# 3           CERR CEsC DMNV KKMP NLIQ PREC                 CTCA OSPD
# 4      CERR NOTI CEsC KKMP MOVM NLIQ PREC            CTOK OTAU OTEF
# ...                                   ...                       ...
# 29966                                 NaN                       NaN
# 29967                                 NaN                       NaN
# 29968                                 NaN                       NaN
# 29969                                 NaN                       NaN
# 29970                                 NaN                       NaN
#
#                                        Texto explicativo    Zona  ...  \
# 0      09.01.2018 10:02:54 NESTOR EFREN SANCHEZ MONTA...  Zona 3  ...
# 1      11.01.2018 15:45:45 NESTOR EFREN SANCHEZ MONTA...  Zona 3  ...
# 2      15.01.2018 18:59:08 ELIAS MAURICIO RAMIREZ BUI...  Zona 3  ...
# 3      15.01.2018 19:03:04 ELIAS MAURICIO RAMIREZ BUI...  Zona 3  ...
# 4      15.01.2018 21:18:16 ELIAS MAURICIO RAMIREZ BUI...  Zona 3  ...
# ...                                                  ...     ...  ...
# 29966  19.09.2022 06:20:32 Elkin Henry Supanteve Rami...  Zona 3  ...
# 29967  19.09.2022 06:34:21 EDUARD YESID RIVERA PINTO ...  Zona 1  ...
# 29968  19.09.2022 07:28:10  WILLIAM ANDRES BENITO CAN...  Zona 3  ...
# 29969  19.09.2022 07:38:44 Elkin Henry Supanteve Rami...  Zona 3  ...
# 29970  19.09.2022 07:45:33 Elkin Henry Supanteve Rami...  Zona 3  ...
#
#       Pendiente clasif.           Proceso de gestión  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# 2                   NaN                          NaN
# 3                   NaN                          NaN
# 4                   NaN                          NaN
# ...                 ...                          ...
# 29966               1.0                          NaN
# 29967               0.0  Mantenimiento por condición
# 29968               1.0                          NaN
# 29969               1.0                          NaN
# 29970               1.0                          NaN
#
#       Tipo de falla / incidente SP Modo de pérdida de contención  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 29966                          NaN                           NaN
# 29967                    No aplica                           NaN
# 29968                          NaN                           NaN
# 29969                          NaN                           NaN
# 29970                          NaN                           NaN
#
#       Producto fugado Cantidad fugada  \
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 29966             NaN             NaN
# 29967             NaN             NaN
# 29968             NaN             NaN
# 29969             NaN             NaN
# 29970             NaN             NaN
#
#                                     Comentarios  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 29966                                       NaN
# 29967  Aviso por condicion de cambio de filtros
# 29968                                       NaN
# 29969                                       NaN
# 29970                                       NaN
#
#       Quien realiza la investigación Tipo investigación / Metodología  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ...                              ...                              ...
# 29966                            NaN                              NaN
# 29967                            NaN                              NaN
# 29968                            NaN                              NaN
# 29969                            NaN                              NaN
# 29970                            NaN                              NaN
#
#       Cod. Investigación
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 29966                NaN
# 29967                NaN
# 29968                NaN
# 29969                NaN
# 29970                NaN
#
# [29971 rows x 60 columns]
#          palabra clave             columna de búsqueda clasificación  \
# 0       acompañamiento        Descripción preprocesado     No aplica
# 1      actividad patio        Descripción preprocesado     No aplica
# 2    afectacion bombeo  Texto explicativo preprocesado         Falla
# 3    afectacion bombeo        Descripción preprocesado         Falla
# 4         afloramiento        Descripción preprocesado         Falla
# ..                 ...                             ...           ...
# 175           traslado        Descripción preprocesado     No aplica
# 176          ubicación        Descripción preprocesado     No aplica
# 177         vegetacion        Descripción preprocesado     No aplica
# 178              verde        Descripción preprocesado     No aplica
# 179             visita        Descripción preprocesado     No aplica
#
#           proceso de gestión
# 0                  No aplica
# 1                  No aplica
# 2    Eliminación de defectos
# 3    Eliminación de defectos
# 4      Seguridad de procesos
# ..                       ...
# 175                No aplica
# 176                No aplica
# 177                No aplica
# 178                No aplica
# 179                No aplica
#
# [180 rows x 4 columns]
#                        Corrector
# Palabra
# aa             aireacondicionado
# aaceito                   aceite
# aacon          aireacondicionado
# aatascamiento       atascamiento
# abajo                      abajo
# ...                          ...
# zon                         zona
# zona                        zona
# zonas                       zona
# zsc                          zsc
# zsv                          zsv
#
# [5537 rows x 1 columns]
#                  Corrector
# Palabra
# afectacion      afectacion
# afectaciones    afectacion
# aflora        afloramiento
# afloramiento  afloramiento
# afloramiet    afloramiento
# ...                    ...
# unidda              unidad
# uniddad             unidad
# unides              unidad
# unididad            unidad
# unidsd              unidad
#
# [248 rows x 1 columns]

# %%
df_total = pd.read_excel('qFallas.xlsx')
df_bow = pd.read_excel('BoW clasificación de avisos.xlsx')
df_dic_da = pd.read_excel('Diccionario DA.xlsx', index_col='Palabra')
df_dic_te = pd.read_excel('Diccionario TE.xlsx', index_col='Palabra')
# Out:
#            Aviso                               Descripción Status del sistema  \
# 0       10293264      Alta temperatura en rodamiento bomba          MECE ORAS
# 1       10293467            TUBING DE VENTEO EN MAL ESTADO          MECE ORAS
# 2       10293691             valvula presenta atascamiento          MECE ORAS
# 3       10293692             valvula presenta atascamiento          MECE ORAS
# 4       10293695  Falla señal de activación en HMI DLC5701          MECE ORAS
# ...          ...                                       ...                ...
# 29966  120025862  Embrague  Unidad 40 MON III-FALLA DE EMG               MEAB
# 29967  120025863    ALTO DIFERENCIAL TORRE DE LUBRICANTE A               MEAB
# 29968  120025864   LIT-0554 PRESENTA DESVIACION PARAMETROS               MEAB
# 29969  120025865          Unidad 1 BPC-3410-FALLA EMBRAGUE               MEAB
# 29970  120025866         Unidad  -4420 BAJO  NIVEL DE AGUA               MEAB
#
#       Status de usuario      Orden Clase de orden  \
# 0                  AVDG  4603258.0           Z2PM
# 1                  AVDG  4606021.0           Z2PM
# 2                  AVDG  4625591.0           Z2PM
# 3                  AVDG  4625592.0           Z2PM
# 4                  AVDG  4601806.0           Z2PM
# ...                 ...        ...            ...
# 29966              AVAB        NaN            NaN
# 29967              AVAB        NaN            NaN
# 29968              AVAB        NaN            NaN
# 29969              AVAB        NaN            NaN
# 29970              AVAB        NaN            NaN
#
#                Status del sistema (orden) Status de usuario (orden)  \
# 0      CERR NOTI CEsC KKMP MOVM NLIQ PREC            CTOK OTAU OTEF
# 1           CERR CEsC DMNV KKMP NLIQ PREC                 CTCA OSPD
# 2           CERR CEsC DMNV KKMP NLIQ PREC                 CTCA OSPD
# 3           CERR CEsC DMNV KKMP NLIQ PREC                 CTCA OSPD
# 4      CERR NOTI CEsC KKMP MOVM NLIQ PREC            CTOK OTAU OTEF
# ...                                   ...                       ...
# 29966                                 NaN                       NaN
# 29967                                 NaN                       NaN
# 29968                                 NaN                       NaN
# 29969                                 NaN                       NaN
# 29970                                 NaN                       NaN
#
#                                        Texto explicativo    Zona  ...  \
# 0      09.01.2018 10:02:54 NESTOR EFREN SANCHEZ MONTA...  Zona 3  ...
# 1      11.01.2018 15:45:45 NESTOR EFREN SANCHEZ MONTA...  Zona 3  ...
# 2      15.01.2018 18:59:08 ELIAS MAURICIO RAMIREZ BUI...  Zona 3  ...
# 3      15.01.2018 19:03:04 ELIAS MAURICIO RAMIREZ BUI...  Zona 3  ...
# 4      15.01.2018 21:18:16 ELIAS MAURICIO RAMIREZ BUI...  Zona 3  ...
# ...                                                  ...     ...  ...
# 29966  19.09.2022 06:20:32 Elkin Henry Supanteve Rami...  Zona 3  ...
# 29967  19.09.2022 06:34:21 EDUARD YESID RIVERA PINTO ...  Zona 1  ...
# 29968  19.09.2022 07:28:10  WILLIAM ANDRES BENITO CAN...  Zona 3  ...
# 29969  19.09.2022 07:38:44 Elkin Henry Supanteve Rami...  Zona 3  ...
# 29970  19.09.2022 07:45:33 Elkin Henry Supanteve Rami...  Zona 3  ...
#
#       Pendiente clasif.           Proceso de gestión  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# 2                   NaN                          NaN
# 3                   NaN                          NaN
# 4                   NaN                          NaN
# ...                 ...                          ...
# 29966               1.0                          NaN
# 29967               0.0  Mantenimiento por condición
# 29968               1.0                          NaN
# 29969               1.0                          NaN
# 29970               1.0                          NaN
#
#       Tipo de falla / incidente SP Modo de pérdida de contención  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 29966                          NaN                           NaN
# 29967                    No aplica                           NaN
# 29968                          NaN                           NaN
# 29969                          NaN                           NaN
# 29970                          NaN                           NaN
#
#       Producto fugado Cantidad fugada  \
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 29966             NaN             NaN
# 29967             NaN             NaN
# 29968             NaN             NaN
# 29969             NaN             NaN
# 29970             NaN             NaN
#
#                                     Comentarios  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 29966                                       NaN
# 29967  Aviso por condicion de cambio de filtros
# 29968                                       NaN
# 29969                                       NaN
# 29970                                       NaN
#
#       Quien realiza la investigación Tipo investigación / Metodología  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ...                              ...                              ...
# 29966                            NaN                              NaN
# 29967                            NaN                              NaN
# 29968                            NaN                              NaN
# 29969                            NaN                              NaN
# 29970                            NaN                              NaN
#
#       Cod. Investigación
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 29966                NaN
# 29967                NaN
# 29968                NaN
# 29969                NaN
# 29970                NaN
#
# [29971 rows x 60 columns]
#          palabra clave             columna de búsqueda clasificación  \
# 0       acompañamiento        Descripción preprocesado     No aplica
# 1      actividad patio        Descripción preprocesado     No aplica
# 2    afectacion bombeo  Texto explicativo preprocesado         Falla
# 3    afectacion bombeo        Descripción preprocesado         Falla
# 4         afloramiento        Descripción preprocesado         Falla
# ..                 ...                             ...           ...
# 175           traslado        Descripción preprocesado     No aplica
# 176          ubicación        Descripción preprocesado     No aplica
# 177         vegetacion        Descripción preprocesado     No aplica
# 178              verde        Descripción preprocesado     No aplica
# 179             visita        Descripción preprocesado     No aplica
#
#           proceso de gestión
# 0                  No aplica
# 1                  No aplica
# 2    Eliminación de defectos
# 3    Eliminación de defectos
# 4      Seguridad de procesos
# ..                       ...
# 175                No aplica
# 176                No aplica
# 177                No aplica
# 178                No aplica
# 179                No aplica
#
# [180 rows x 4 columns]
#                        Corrector
# Palabra
# aa             aireacondicionado
# aaceito                   aceite
# aacon          aireacondicionado
# aatascamiento       atascamiento
# abajo                      abajo
# ...                          ...
# zon                         zona
# zona                        zona
# zonas                       zona
# zsc                          zsc
# zsv                          zsv
#
# [5537 rows x 1 columns]
#                  Corrector
# Palabra
# afectacion      afectacion
# afectaciones    afectacion
# aflora        afloramiento
# afloramiento  afloramiento
# afloramiet    afloramiento
# ...                    ...
# unidda              unidad
# uniddad             unidad
# unides              unidad
# unididad            unidad
# unidsd              unidad
#
# [248 rows x 1 columns]

# %%
preprocesamiento()
# Out:
#                        Descripción preprocesado
# 0         alta temperatura en rodamientos bomba
# 1                  tubbing venteo en mal estado
# 2                 valvula presenta atascamiento
# 3                 valvula presenta atascamiento
# 4                 falla señal activacion en hmi
# ...                                         ...
# 29966  embrague unidad mon iii falla emergencia
# 29967         alta diferencial torre lubricante
# 29968            presenta desviacion parametros
# 29969                     unidad falla embrague
# 29970                    unidad baja nivel agua
#
# [29971 rows x 1 columns]
#                           Texto explicativo preprocesado
# 0      nestor efren sanchez montanez durante funciona...
# 1      nestor efren sanchez montanez en pruebas perio...
# 2      elias mauricio ramirez buitrago valvula presen...
# 3      elias mauricio ramirez buitrago valvula presen...
# 4      elias mauricio ramirez buitrago en pantalla hm...
# ...                                                  ...
# 29966  elkin henry supanteve ramirez embrague unidad ...
# 29967  eduard yesid rivera pinto tel torre de lubrica...
# 29968  william andres benito cano durante despacho ag...
# 29969  elkin henry supanteve ramirez bomba centrifuga...
# 29970  elkin henry supanteve ramirez unidad bajo nive...
#
# [29971 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29971 entries, 0 to 29970
# Data columns (total 65 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Aviso                                   29971 non-null  int64
#  1   Descripción                             29971 non-null  object
#  2   Status del sistema                      29971 non-null  object
#  3   Status de usuario                       29943 non-null  object
#  4   Orden                                   26351 non-null  float64
#  5   Clase de orden                          26350 non-null  object
#  6   Status del sistema (orden)              26351 non-null  object
#  7   Status de usuario (orden)               26351 non-null  object
#  8   Texto explicativo                       29971 non-null  object
#  9   Zona                                    29971 non-null  object
#  10  Estación                                29971 non-null  object
#  11  Sistema                                 29954 non-null  object
#  12  Ubicación técnica                       29971 non-null  object
#  13  Denominación de la ubicación técnica    29971 non-null  object
#  14  Perfil de catálogo                      29971 non-null  object
#  15  Clase tipo de equipo                    29970 non-null  object
#  16  Equipo                                  29971 non-null  int64
#  17  Denominación de objeto técnico          29971 non-null  object
#  18  Especialidad                            29971 non-null  object
#  19  Crítico                                 29971 non-null  object
#  20  Repercusión                             26363 non-null  object
#  21  Est.ins.tras avería                     29971 non-null  object
#  22  Semana                                  29971 non-null  object
#  23  Inicio de avería                        29971 non-null  datetime64[ns]
#  24  Hora de inicio de avería                29971 non-null  object
#  25  Fin de avería                           27041 non-null  datetime64[ns]
#  26  Hora de fin de avería                   27041 non-null  object
#  27  Parada                                  5446 non-null   object
#  28  Duración de parada                      29971 non-null  float64
#  29  Prioridad                               29965 non-null  object
#  30  Grupo códigos 1                         29971 non-null  object
#  31  Cód.codificación                        29971 non-null  object
#  32  Texto código p. codificación            29971 non-null  object
#  33  Parte del objeto                        28296 non-null  object
#  34  Texot grupo de códigos p. parte objeto  28295 non-null  object
#  35  Código parte objeto                     28296 non-null  object
#  36  Texto código parte objeto               28295 non-null  object
#  37  Grupo códigos 2                         29971 non-null  object
#  38  Texto grupo de códigos para problema    29971 non-null  object
#  39  Código de averia                        29971 non-null  object
#  40  Texto código del problema               29971 non-null  object
#  41  Texto posición                          29971 non-null  object
#  42  Grupo códigos 3                         28000 non-null  object
#  43  Texto grupos de códigos p. motivo       27181 non-null  object
#  44  Código de causas                        28000 non-null  object
#  45  Texto código motivo                     27181 non-null  object
#  46  Texto de la causa                       26204 non-null  object
#  47  Afecta operación                        29954 non-null  object
#  48  Facilitador de la metodología           29971 non-null  object
#  49  #                                       29971 non-null  int64
#  50  Pendiente clasif.                       15915 non-null  float64
#  51  Proceso de gestión                      22043 non-null  object
#  52  Tipo de falla / incidente SP            21969 non-null  object
#  53  Modo de pérdida de contención           1065 non-null   object
#  54  Producto fugado                         1051 non-null   object
#  55  Cantidad fugada                         631 non-null    object
#  56  Comentarios                             10251 non-null  object
#  57  Quien realiza la investigación          522 non-null    object
#  58  Tipo investigación / Metodología        219 non-null    object
#  59  Cod. Investigación                      451 non-null    object
#  60  Descripción preprocesado                29971 non-null  object
#  61  Texto explicativo preprocesado          29971 non-null  object
#  62  Clasificación                           0 non-null      float64
#  63  Proceso gestión                         0 non-null      float64
#  64  Tipo falla / SP                         0 non-null      float64
# dtypes: datetime64[ns](2), float64(6), int64(3), object(54)
# memory usage: 14.9+ MB
# None
# (29971, 65)
